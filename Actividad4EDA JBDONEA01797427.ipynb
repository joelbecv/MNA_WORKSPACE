# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 4**
# Exploración de datos
#
# ---

# %% [markdown]
# GIT HUB REV
# *   NOMBRE: JOEL ARTURO BECERRIL BALDERAS
# *   MATRÍCULA: A01797427-

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
DIR = "/content/drive/MyDrive/maestria/IA/Tec/Ciencia_de_datos/Semana4"
os.chdir(DIR)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("credit_risk_dataset.csv")
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32581 rows x 12 columns]

# %%
df.shape
# Out:
# (32581, 12)

# %% [markdown]
# # **Parte 1**. Análisis descriptivo (univariante)

# %% [markdown]
# 1. Utiliza el método `info()` del dataframe, para obtener el resumen de los tipos de datos. ¿Cuántas columnas son numéricas y cuántas cualitativas?
# **RESPUESTA 8 NUMERICOS Y 4 CUALITATIVOS**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
#  2. Determina el porcentaje de valores faltantes por columna.

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
# Calculate the percentage of missing values per column
missing_percentage = df.isnull().sum() * 100 / len(df)
missing_percentage
# Out:
# person_age                    0.000000
# person_income                 0.000000
# person_home_ownership         0.000000
# person_emp_length             2.747000
# loan_intent                   0.000000
# loan_grade                    0.000000
# loan_amnt                     0.000000
# loan_int_rate                 9.563856
# loan_status                   0.000000
# loan_percent_income           0.000000
# cb_person_default_on_file     0.000000
# cb_person_cred_hist_length    0.000000
# dtype: float64

# %% [markdown]
# # Análisis de variables numéricas

# %% [markdown]
# 3. Obtén las siguientes estadísticas descriptivas para todas las variables numéricas:
# *   Tendencia central (media, mediana)
# *   Dispersión o variabilidad (min, max, desviación estándar, cuartiles)
# *   Forma (asimetría y curtosis)
# *   Clasifica las variables `person_age` y `loan_in_rate` según los valores observados de asimetría y curtosis
#
# **NOTA**. Recuerda que muchas de estas estadísticas, puedes obtenerlas utilizando la función `describe()` y que la mediana está representada en el 2do cuartil (50%)

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# 50%        10.990000      0.000000             0.150000
# 75%        13.470000      0.000000             0.230000
# max        23.220000      1.000000             0.830000
#
#        cb_person_cred_hist_length
# count                32581.000000
# mean                     5.804211
# std                      4.055001
# min                      2.000000
# 25%                      3.000000
# 50%                      4.000000
# 75%                      8.000000
# max                     30.000000

# %%
numeric_df = df.select_dtypes(include=np.number) #CTOMA SOLO LOS DATOS NUMERICOS XQ SI NO MARCA ERROR
numeric_df.skew() #CALCULA ASIMETRIA
# Out:
# person_age                     2.581393
# person_income                 32.865349
# person_emp_length              2.614455
# loan_amnt                      1.192477
# loan_int_rate                  0.208550
# loan_status                    1.364888
# loan_percent_income            1.064669
# cb_person_cred_hist_length     1.661790
# dtype: float64

# %%
numeric_df.kurt() #CALCULA CURTOSIS
# Out:
# person_age                      18.560825
# person_income                 2693.272776
# person_emp_length               43.722338
# loan_amnt                        1.423565
# loan_int_rate                   -0.671609
# loan_status                     -0.137088
# loan_percent_income              1.223687
# cb_person_cred_hist_length       3.716194
# dtype: float64

# %% [markdown]
# 4. Utiliza histogramas para determinar la distribución de los valores representados en cada variable.
# *   ¿Se corresponde con lo obtenido en el cálculo de asimetría? Como verás, los datos reales son más complejos que la teoría. Por esta razón, recuerda siempre acompañar el análisis de la asimetría con algún gráfico como un histograma.
#
# **NOTA**. Para esto también puedes ocupar los gráficos `kde` ([kernel density estimation](https://www.cienciadedatos.net/documentos/pystats02-kernel-density-estimation-kde-python.html)) que crean una curva continua y suave expandiendo la idea del histograma.

# %%
# HISTOGRAMAS CON KERNEL DENSITY ESTIMATION

# pasa por cada columna numerica
for column in numeric_df.columns:
    plt.figure(figsize=(6, 4))  # ajusta el tamaño de la figura
    sns.histplot(df[column], kde=True)  #  KDE=true  crean una curva continua y suave expandiendo la idea del histograma.
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show() #detiene el for

# %% [markdown]
# 5. Emplea boxplots para mostrar la distribución de los datos a través de sus cuartiles.

# %%
# crea boxplots para los datos numericos
for column in numeric_df.columns: # pasa por cada columna numerica
    plt.figure(figsize=(6, 4))  # ajusta el tamaño de la figura
    sns.boxplot(y=df[column]) #crea boxplot
    plt.title(f'Boxplot de {column}')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# *   Como podrás observar hay valores atípicos en todas las variables. Ejecuta el siguiente código para identificar los valores atípicos en la variable `person_age`

# %%
percentile_25 = df["person_age"].quantile(0.25)
percentile_75 = df["person_age"].quantile(0.75)
iqr = percentile_75 - percentile_25
upper_limit = percentile_75 + 1.5 * iqr
lower_limit = percentile_25 - 1.5 * iqr
IQR_outliers = df[(df["person_age"] < lower_limit) | (df["person_age"] > upper_limit)]
IQR_outliers
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 29121          50         900000              MORTGAGE               11.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81               VENTURE          C       4800          13.57            0
# 183            EDUCATION          B       6000          11.86            0
# 575            EDUCATION          B      20400          10.25            0
# 747              VENTURE          B      20000            NaN            0
# 29121  DEBTCONSOLIDATION          B      30000          12.69            0
# ...                  ...        ...        ...            ...          ...
# 32576           PERSONAL          C       5800          13.16            0
# 32577           PERSONAL          A      17625           7.49            0
# 32578    HOMEIMPROVEMENT          B      35000          10.99            1
# 32579           PERSONAL          B      15000          11.48            0
# 32580            MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# 183                   0.03                         N
# 575                   0.25                         N
# 747                   0.26                         N
# 29121                 0.03                         N
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 81                              3
# 183                             2
# 575                             3
# 747                             4
# 29121                          15
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [1494 rows x 12 columns]

# %% [markdown]
# # Análisis de variables de texto

# %% [markdown]
#  6. Obtén las siguientes estadísticas descriptivas para todas las variables de texto:
# *   Tendencia central (moda)
# *   Cardinalidad (cantidad de valores únicos)
# *   Recuentos únicos (número de ocurrencias para cada valor único)
#
# **NOTA**. Un resumen de estas estadísticas, puedes obtenerlas indicando en la función `describe()` que se incluirán sólo las variables de tipo object: `describe(include = 'object')`. Para los recuentos utiliza la función `df['columna'].value_counts()`

# %%
df.describe(include = 'object')
# Out:
#        person_home_ownership loan_intent loan_grade cb_person_default_on_file
# count                  32581       32581      32581                     32581
# unique                     4           6          7                         2
# top                     RENT   EDUCATION          A                         N
# freq                   16446        6453      10777                     26836

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        16446
# MORTGAGE    13444
# OWN          2584
# OTHER         107
# Name: count, dtype: int64

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            6453
# MEDICAL              6071
# VENTURE              5719
# PERSONAL             5521
# DEBTCONSOLIDATION    5212
# HOMEIMPROVEMENT      3605
# Name: count, dtype: int64

# %%
df['loan_grade'].value_counts()
# Out:
# loan_grade
# A    10777
# B    10451
# C     6458
# D     3626
# E      964
# F      241
# G       64
# Name: count, dtype: int64

# %%
df['cb_person_default_on_file'].value_counts()
# Out:
# cb_person_default_on_file
# N    26836
# Y     5745
# Name: count, dtype: int64

# %% [markdown]
# 7. Utiliza gráficos de barras por variable para representar la frecuencia de cada categoría.
#
# **NOTA**. seaborn posee un gráfico de recuento, para variables de tipo object, que calcula la frecuencia de cada categoría sin necesidad de utilizar la función `value_counts()`. Para generarlo debes indicar la columna: `sns.countplot(x='columna', data=df) `

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    ax = sns.countplot(x=col, data=df)  # Obtener el objeto para  Axes
    ax.bar_label(ax.containers[0])  # Agrega etiquetas de valores
    plt.title(f'Frecuencia de categorías para {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Parte 2**. Análisis de correlación (bivariante y multivariante)

# %% [markdown]
# La variable `loan_status` será la variable de salida (o a predecir en un modelo de ML). Analiza su relación con el resto de las variables a través de los siguientes gráficos:
#
# 8. Un box plot para visualizar la distribución de `loan_percent_income` según el `loan_status`. Interpreta el resultado.
#
# **RESPUESTA Se observa que la mediana de loan_percent_income es ligeramente mas alta en los casos de incumplimiento que en los casos que no incumplieron. Sin embargo hay superposicion entre los  grupos. Esto no es suficiente evidencia para decir que el porcentaje de ingresos del préstamo es una buenO para predecir el estatus de incumplimiento del préstamo.**

# %%
#Un box plot para visualizar la distribución de loan_percent_income según el loan_status.

plt.figure(figsize=(6, 4))
sns.boxplot(x='loan_status', y='loan_percent_income', data=df)
plt.title('Distribución de loan_percent_income según loan_status')
plt.xlabel('loan_status')
plt.ylabel('loan_percent_income')
plt.show()

# %% [markdown]
#  9. En los gráficos de barras que obtuviste en el ejercicio 7, separa el conteo según el `load_status`, utilizando el parámetro `hue`.

# %%
# separa el conteo con el parámetro hue.

for col in categorical_cols:
    plt.figure(figsize=(8, 6))
    ax = sns.countplot(x=col, hue='loan_status', data=df)
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    plt.title(f'Frecuencia de categorías para {col} por loan_status')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 10. Un mapa de calor con los valores de correlación de todas las variables del dataframe.
# *   ¿Qué variable tiene mayor correlación con `loan_status`?
#
# **RESPUESTA: La variable con mayor correlación con 'loan_status' es 'loan_percent_income' con un valor de 0.38**

# %%
#  mapa de calor con los valores de correlación de todas las variables del dataframe.


correlation_matrix = df.select_dtypes(include=np.number).corr()

# Creacion de mapa de calor
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

#Variable con más alta correlación con  'loan_status'
correl_C_loan_status = correlation_matrix['loan_status'].drop('loan_status')
correlation_masaltid = correl_C_loan_status.abs().idxmax()
correlation_masalt = correl_C_loan_status[correlation_masaltid]

print(f"La variable con mayor correlación con 'loan_status' es '{correlation_masaltid}' con un valor de {correlation_masalt:.2f}")
# Out:
# La variable con mayor correlación con 'loan_status' es 'loan_percent_income' con un valor de 0.38
