# %% [markdown]
# ![header](https://drive.google.com/uc?export=view&id=1KuEspEp7OwqGw6uMRJvYE6BVE-Zo-8JF)
#
#  <h1> <div align="center"> Dr. David Antonio-Torres</div> </h1>

# %% [markdown]
# # Introducción a Redes Neuronales con Keras
# ### Se intentará resolver un dataset de Scikit-Learn de clasificación binaria usando una neurona y, posteriormente, se añadirán más neuronas para mejorar la clasificación.

# %% [markdown]
# # Se cargan las bibliotecas necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Se carga el dataset *make_moons* de Scikit-Learn con 1500 muestras
# ### https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html

# %%
from sklearn import datasets

noisy_moons = datasets.make_moons(n_samples=2000, noise=.05)
X, y = noisy_moons
print(X.shape)
print(y.shape)
# Out:
# (2000, 2)
# (2000,)

# %%
# Feature #1, feature #2, mientras y da el color de las dos clases
sns.scatterplot(x=X[:, 0],y=X[:, 1], hue = y)
# Out:
# <Axes: >

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %% [markdown]
# # Se crean los sets de entrenamiento y de prueba y se escalan ambos sets de features entre 0 y 1
# ### https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# 25% para el set de prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
# Se escala el set de entrenamiento
scalar = MinMaxScaler()
scalar.fit(X_train)
X_train_scaled = scalar.transform(X_train)
# Se escala el set de prueba
scalar = MinMaxScaler()
scalar.fit(X_test)
X_test_scaled = scalar.transform(X_test)

# %%
# Se grafican los datos escalados
sns.scatterplot(x=X_train_scaled[:, 0], y=X_train_scaled[:, 1], hue=y_train)
# Out:
# <Axes: >

# %% [markdown]
# # Se cargan las bibliotecas necesarias para definir la red neuronal

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %% [markdown]
# # Una sola neurona con dos entradas, una salida.

# %%
model = Sequential()
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy',  metrics=['accuracy'])
# Out:
# /Users/joelbecerril/miniconda3/envs/ml_env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-06-03 23:35:44.781130: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M5
# 2026-06-03 23:35:44.781164: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2026-06-03 23:35:44.781168: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.88 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780551344.781184 2065916 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1780551344.781454 2065916 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
hist = model.fit(x=X_train_scaled, y=y_train, verbose=2, batch_size=50,epochs=100, shuffle='true')
# Out:
# Epoch 1/100
# 2026-06-03 23:35:45.319633: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 30/30 - 1s - 47ms/step - accuracy: 0.3027 - loss: 0.7646
# Epoch 2/100
# 30/30 - 0s - 4ms/step - accuracy: 0.4573 - loss: 0.7048
# Epoch 3/100
# 30/30 - 0s - 4ms/step - accuracy: 0.7833 - loss: 0.6551
# Epoch 4/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8533 - loss: 0.6113
# Epoch 5/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8820 - loss: 0.5730
# Epoch 6/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8833 - loss: 0.5386
# Epoch 7/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8807 - loss: 0.5092
# Epoch 8/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.4831
# Epoch 9/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8753 - loss: 0.4602
# Epoch 10/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8753 - loss: 0.4403
# Epoch 11/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8720 - loss: 0.4227
# Epoch 12/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8740 - loss: 0.4071
# Epoch 13/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8713 - loss: 0.3931
# Epoch 14/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8727 - loss: 0.3807
# Epoch 15/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8733 - loss: 0.3698
# Epoch 16/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8700 - loss: 0.3599
# Epoch 17/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8707 - loss: 0.3514
# Epoch 18/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8680 - loss: 0.3434
# Epoch 19/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8700 - loss: 0.3363
# Epoch 20/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8700 - loss: 0.3298
# Epoch 21/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8693 - loss: 0.3240
# Epoch 22/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8707 - loss: 0.3186
# Epoch 23/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8720 - loss: 0.3139
# Epoch 24/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8693 - loss: 0.3095
# Epoch 25/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8693 - loss: 0.3055
# Epoch 26/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8700 - loss: 0.3018
# Epoch 27/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8720 - loss: 0.2984
# Epoch 28/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8713 - loss: 0.2951
# Epoch 29/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8713 - loss: 0.2922
# Epoch 30/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8733 - loss: 0.2895
# Epoch 31/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8720 - loss: 0.2870
# Epoch 32/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8713 - loss: 0.2847
# Epoch 33/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8713 - loss: 0.2825
# Epoch 34/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8727 - loss: 0.2804
# Epoch 35/100
# 30/30 - 0s - 5ms/step - accuracy: 0.8733 - loss: 0.2785
# Epoch 36/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8740 - loss: 0.2767
# Epoch 37/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8740 - loss: 0.2750
# Epoch 38/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8740 - loss: 0.2736
# Epoch 39/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8747 - loss: 0.2719
# Epoch 40/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8740 - loss: 0.2705
# Epoch 41/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8740 - loss: 0.2693
# Epoch 42/100
# 30/30 - 0s - 5ms/step - accuracy: 0.8753 - loss: 0.2678
# Epoch 43/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8753 - loss: 0.2667
# Epoch 44/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8733 - loss: 0.2659
# Epoch 45/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8753 - loss: 0.2645
# Epoch 46/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8753 - loss: 0.2634
# Epoch 47/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8760 - loss: 0.2624
# Epoch 48/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8753 - loss: 0.2616
# Epoch 49/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8760 - loss: 0.2606
# Epoch 50/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8760 - loss: 0.2599
# Epoch 51/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8760 - loss: 0.2590
# Epoch 52/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8760 - loss: 0.2584
# Epoch 53/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2574
# Epoch 54/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2568
# Epoch 55/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8760 - loss: 0.2561
# Epoch 56/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2555
# Epoch 57/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8773 - loss: 0.2551
# Epoch 58/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8773 - loss: 0.2542
# Epoch 59/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2536
# Epoch 60/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2531
# Epoch 61/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2526
# Epoch 62/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8767 - loss: 0.2523
# Epoch 63/100
# 30/30 - 0s - 5ms/step - accuracy: 0.8780 - loss: 0.2517
# Epoch 64/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8780 - loss: 0.2510
# Epoch 65/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8787 - loss: 0.2508
# Epoch 66/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8787 - loss: 0.2503
# Epoch 67/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8787 - loss: 0.2501
# Epoch 68/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8793 - loss: 0.2498
# Epoch 69/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8800 - loss: 0.2491
# Epoch 70/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8787 - loss: 0.2488
# Epoch 71/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8793 - loss: 0.2484
# Epoch 72/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8807 - loss: 0.2478
# Epoch 73/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8800 - loss: 0.2477
# Epoch 74/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8807 - loss: 0.2473
# Epoch 75/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8807 - loss: 0.2470
# Epoch 76/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8800 - loss: 0.2469
# Epoch 77/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8793 - loss: 0.2465
# Epoch 78/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8827 - loss: 0.2461
# Epoch 79/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8827 - loss: 0.2456
# Epoch 80/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8813 - loss: 0.2454
# Epoch 81/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8827 - loss: 0.2454
# Epoch 82/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8800 - loss: 0.2456
# Epoch 83/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8840 - loss: 0.2449
# Epoch 84/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8827 - loss: 0.2445
# Epoch 85/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8833 - loss: 0.2443
# Epoch 86/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8833 - loss: 0.2440
# Epoch 87/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8847 - loss: 0.2441
# Epoch 88/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8847 - loss: 0.2438
# Epoch 89/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8840 - loss: 0.2434
# Epoch 90/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8840 - loss: 0.2432
# Epoch 91/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8847 - loss: 0.2430
# Epoch 92/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8860 - loss: 0.2430
# Epoch 93/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8853 - loss: 0.2426
# Epoch 94/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8847 - loss: 0.2429
# Epoch 95/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8860 - loss: 0.2424
# Epoch 96/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8840 - loss: 0.2424
# Epoch 97/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8860 - loss: 0.2421
# Epoch 98/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8867 - loss: 0.2420
# Epoch 99/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8867 - loss: 0.2420
# Epoch 100/100
# 30/30 - 0s - 4ms/step - accuracy: 0.8853 - loss: 0.2418

# %% [markdown]
# # Se muestra un resumen del modelo, así como la evaluación de los resultados

# %%
# resumen del model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11 (48.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8 (36.00 B)

# %%
# Exactitud del modelo
plt.plot(hist.history['accuracy']) 
plt.legend(['Exactitud'])
plt.ylabel('Exactitud')
plt.xlabel('Epoca')
# Out:
# Text(0.5, 0, 'Epoca')

# %%
# Función de pérdida
plt.plot(hist.history['loss'])
plt.legend(['Error'])
plt.title('Error')
plt.xlabel('Epoca')
# Out:
# Text(0.5, 0, 'Epoca')

# %%
from matplotlib.colors import ListedColormap
X_grid, y_grid = X_train_scaled, y_train

X1, X2 = np.meshgrid(np.arange(start = X_grid[:, 0].min() , stop = X_grid[:, 0].max(), step = 0.01),
                     np.arange(start = X_grid[:, 1].min(), stop = X_grid[:, 1].max(), step = 0.01))

plt.contourf(X1, X2, model.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

for i, j in enumerate(np.unique(y_grid)):
    plt.scatter(X_grid[y_grid == j, 0], X_grid[y_grid == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
    
plt.title('Resultados del Entrenamiento')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /var/folders/hq/qxbmfm3j3555w59yn3g3dvnm0000gn/T/ipykernel_51310/3145507442.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_grid[y_grid == j, 0], X_grid[y_grid == j, 1],

# %%
# Se calculan las predicciones del modelo para graficar la matriz de confusión
# Se compara contra 0.5 para determinar si es clase 0 ó clase 1
# ya que la salida que da la función Sigmoid es continua entre 0 y 1
y_predict = (model.predict(X_test_scaled) > 0.5).astype("int32")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test, y_predict)

sns.heatmap(cm, annot=True, fmt="d")
# Out:
# <Axes: >

# %% [markdown]
# # Se agregan dos capas de neuronas entre la entrada y salida y se repiten los pasos anteriores

# %%
model = Sequential()
# capa de oculta con 20 nodos
model.add(Dense(units=20, input_dim=2, activation='relu'))
# capa oculta con 10 neuronas
model.add(Dense(units=10, activation='relu'))
# capa oculta con 10 neuronas
model.add(Dense(units=10, activation='relu'))
# capa de salida con una neurona 
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy',  metrics=['accuracy'])
# Out:
# /Users/joelbecerril/miniconda3/envs/ml_env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
hist = model.fit(x=X_train_scaled, y=y_train, verbose=2, batch_size=50,epochs=100, shuffle='true')
# Out:
# Epoch 1/100
# 30/30 - 2s - 64ms/step - accuracy: 0.8313 - loss: 0.4704
# Epoch 2/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8707 - loss: 0.2649
# Epoch 3/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8700 - loss: 0.2932
# Epoch 4/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8767 - loss: 0.2595
# Epoch 5/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8853 - loss: 0.2415
# Epoch 6/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8860 - loss: 0.2438
# Epoch 7/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8867 - loss: 0.2414
# Epoch 8/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8800 - loss: 0.2497
# Epoch 9/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8853 - loss: 0.2407
# Epoch 10/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8833 - loss: 0.2401
# Epoch 11/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8847 - loss: 0.2409
# Epoch 12/100
# 30/30 - 0s - 7ms/step - accuracy: 0.8847 - loss: 0.2421
# Epoch 13/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8820 - loss: 0.2410
# Epoch 14/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8847 - loss: 0.2454
# Epoch 15/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8713 - loss: 0.2570
# Epoch 16/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8773 - loss: 0.2494
# Epoch 17/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8793 - loss: 0.2555
# Epoch 18/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8840 - loss: 0.2480
# Epoch 19/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8747 - loss: 0.2669
# Epoch 20/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8840 - loss: 0.2581
# Epoch 21/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8720 - loss: 0.2593
# Epoch 22/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8787 - loss: 0.2697
# Epoch 23/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8793 - loss: 0.2522
# Epoch 24/100
# 30/30 - 0s - 7ms/step - accuracy: 0.8807 - loss: 0.2495
# Epoch 25/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8793 - loss: 0.2502
# Epoch 26/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8813 - loss: 0.2481
# Epoch 27/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8700 - loss: 0.2653
# Epoch 28/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8593 - loss: 0.3350
# Epoch 29/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8473 - loss: 0.3274
# Epoch 30/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8613 - loss: 0.3057
# Epoch 31/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8527 - loss: 0.3809
# Epoch 32/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8567 - loss: 0.3125
# Epoch 33/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8200 - loss: 0.5120
# Epoch 34/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8613 - loss: 0.3493
# Epoch 35/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8473 - loss: 0.4620
# Epoch 36/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8507 - loss: 0.3750
# Epoch 37/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8447 - loss: 0.5204
# Epoch 38/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8313 - loss: 0.6393
# Epoch 39/100
# 30/30 - 0s - 7ms/step - accuracy: 0.7953 - loss: 0.9608
# Epoch 40/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7853 - loss: 1.3663
# Epoch 41/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7867 - loss: 1.3305
# Epoch 42/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7993 - loss: 1.1381
# Epoch 43/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7960 - loss: 1.4759
# Epoch 44/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7807 - loss: 1.8752
# Epoch 45/100
# 30/30 - 0s - 8ms/step - accuracy: 0.6947 - loss: 4.3772
# Epoch 46/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8113 - loss: 1.3232
# Epoch 47/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8327 - loss: 0.9324
# Epoch 48/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8047 - loss: 1.6192
# Epoch 49/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7327 - loss: 4.3350
# Epoch 50/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7920 - loss: 2.5565
# Epoch 51/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7473 - loss: 3.2648
# Epoch 52/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7347 - loss: 4.9429
# Epoch 53/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8013 - loss: 2.5691
# Epoch 54/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8173 - loss: 2.0719
# Epoch 55/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7833 - loss: 3.7237
# Epoch 56/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8240 - loss: 1.9379
# Epoch 57/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7807 - loss: 4.6255
# Epoch 58/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7753 - loss: 3.7895
# Epoch 59/100
# 30/30 - 0s - 8ms/step - accuracy: 0.6967 - loss: 10.9660
# Epoch 60/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7880 - loss: 3.7631
# Epoch 61/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8087 - loss: 3.1645
# Epoch 62/100
# 30/30 - 0s - 10ms/step - accuracy: 0.8213 - loss: 2.9201
# Epoch 63/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8153 - loss: 3.3893
# Epoch 64/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7580 - loss: 6.7722
# Epoch 65/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7620 - loss: 7.2402
# Epoch 66/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8000 - loss: 4.5915
# Epoch 67/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7673 - loss: 8.3218
# Epoch 68/100
# 30/30 - 0s - 9ms/step - accuracy: 0.8053 - loss: 5.7766
# Epoch 69/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7473 - loss: 8.7474
# Epoch 70/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8333 - loss: 3.2636
# Epoch 71/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8240 - loss: 3.7968
# Epoch 72/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7880 - loss: 6.9339
# Epoch 73/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7553 - loss: 10.5654
# Epoch 74/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7167 - loss: 14.7676
# Epoch 75/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7867 - loss: 7.4544
# Epoch 76/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7653 - loss: 10.4704
# Epoch 77/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7580 - loss: 11.3465
# Epoch 78/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8267 - loss: 4.6388
# Epoch 79/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8133 - loss: 6.5071
# Epoch 80/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8320 - loss: 4.9423
# Epoch 81/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8087 - loss: 7.3434
# Epoch 82/100
# 30/30 - 0s - 12ms/step - accuracy: 0.7693 - loss: 11.3409
# Epoch 83/100
# 30/30 - 0s - 13ms/step - accuracy: 0.7200 - loss: 27.4152
# Epoch 84/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7887 - loss: 10.6003
# Epoch 85/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7140 - loss: 25.2786
# Epoch 86/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8167 - loss: 9.4442
# Epoch 87/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8040 - loss: 9.0937
# Epoch 88/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7747 - loss: 13.5435
# Epoch 89/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8280 - loss: 7.1013
# Epoch 90/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7707 - loss: 15.3020
# Epoch 91/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7747 - loss: 16.2533
# Epoch 92/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8120 - loss: 9.7034
# Epoch 93/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7720 - loss: 16.9538
# Epoch 94/100
# 30/30 - 0s - 8ms/step - accuracy: 0.8093 - loss: 11.5653
# Epoch 95/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7347 - loss: 22.6873
# Epoch 96/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7907 - loss: 17.1160
# Epoch 97/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7707 - loss: 18.7549
# Epoch 98/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7953 - loss: 13.6256
# Epoch 99/100
# 30/30 - 0s - 8ms/step - accuracy: 0.7253 - loss: 29.8336
# Epoch 100/100
# 30/30 - 0s - 9ms/step - accuracy: 0.7313 - loss: 31.7922

# %%
# resumen del model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 20)             │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,175 (4.59 KB)
#  Trainable params: 391 (1.53 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 784 (3.07 KB)

# %%
# Exactitud del modelo
plt.plot(hist.history['accuracy']) 
plt.legend(['Exactitud'])
plt.ylabel('Exactitud')
plt.xlabel('Epoca')
# Out:
# Text(0.5, 0, 'Epoca')

# %%
# Función de pérdida
plt.plot(hist.history['loss'])
plt.legend(['Error'])
plt.title('Error')
plt.xlabel('Epoca')
# Out:
# Text(0.5, 0, 'Epoca')

# %%
from matplotlib.colors import ListedColormap
X_grid, y_grid = X_train_scaled, y_train

X1, X2 = np.meshgrid(np.arange(start = X_grid[:, 0].min() , stop = X_grid[:, 0].max(), step = 0.01),
                     np.arange(start = X_grid[:, 1].min(), stop = X_grid[:, 1].max(), step = 0.01))

plt.contourf(X1, X2, model.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

for i, j in enumerate(np.unique(y_grid)):
    plt.scatter(X_grid[y_grid == j, 0], X_grid[y_grid == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
    
plt.title('Resultados del Entrenamiento')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# /var/folders/hq/qxbmfm3j3555w59yn3g3dvnm0000gn/T/ipykernel_51310/3145507442.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_grid[y_grid == j, 0], X_grid[y_grid == j, 1],

# %%
# Se calculan las predicciones del modelo para graficar la matriz de confusión
# Se compara contra 0.5 para determinar si es clase 0 ó clase 1
# ya que la salida que da la función Sigmoid es continua entre 0 y 1
y_predict = (model.predict(X_test_scaled) > 0.5).astype("int32")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test, y_predict)

sns.heatmap(cm, annot=True, fmt="d")
# Out:
# <Axes: >

# %% [markdown]
# # Gracias por la atención
