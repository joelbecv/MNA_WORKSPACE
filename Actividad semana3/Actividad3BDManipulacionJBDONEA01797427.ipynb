# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 3**
# Bases, almacenes y manipulación de datos
#
# ---

# %% [markdown]
# *   NOMBRE: JOEL ARTURO BECERRIL BALDERAS
# *   MATRÍCULA: A01797427

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás la base de datos relacional `classicmodels` (MySQL), compuesta por las siguientes tablas:
#
# *   `Customers`: almacena los datos de los clientes.
# *   `Products`: almacena una lista de modelos de coches a escala.
# *   `ProductLines`: almacena una lista de categorías de líneas de productos.
# *   `Orders`: almacena los pedidos de venta realizados por los clientes.
# *   `OrderDetails`: almacena elementos de línea de pedidos de ventas para cada pedido de ventas.
# *   `Payments`: almacena los pagos realizados por los clientes en función de sus cuentas.
# *   `Employees`: almacena toda la información de los empleados, así como la estructura de la organización, como quién informa a quién.
# *   `Offices`: almacena los datos de la oficina de ventas.
#
# Revisa con detalle su esquema para que comprendas cómo se relacionan las tablas anteriores.

# %% [markdown]
# Recuerda que:
#
#
# *   Una **clave primaria** es un atributo (o conjunto) que identifica unívocamente a cada registro en la tabla.
# *   Una **clave foránea** (externa o ajena) es un atributos (o conjunto) en una tabla que es una clave primaria en otra (o posiblemente la misma) tabla.
# *   Las **relaciones** son las líneas que conectan una tabla con otra y el extremo determina la cardinalidad. Las relaciones con línea continua (identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser foránea y primaria (al mismo tiempo) de otra. Las relaciones con línea discontinua (no identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser sólo foránea en otra.

# %% [markdown]
# # **Parte 1**. SQLAlchemy y SQL básico

# %%
#This line of code is like telling your computer: "I need a tool called pymysql to work with MySQL databases.  download and install it for me."
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %% [markdown]
# 1.	Crea el motor `sqlalchemy`, con el método `create_engine()` y una conexión con `connect()` como se muestra a continuación:

# %%
import sqlalchemy as sqla
import pymysql
import pandas as pd

# %%
# Crear el motor (dialecto://usuarioBD:clave@ipHostDBMS:puerto/esquema
db = sqla.create_engine('mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.217.214:3306/classicmodels', pool_recycle=3600)

# Crea una conexión para luego invocar declaraciones SQL
conn = db.connect()

# %% [markdown]
# Escribe las consultas en SQL para obtener:

# %% [markdown]
# 2.	La información de las líneas de productos.

# %%
query = sqla.text ("SELECT * FROM productlines;")
productlines_df = pd.read_sql_query(query, conn)
productlines_df
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# 3.	La información de los empleados ordenados por nombre (`firstName`).

# %%
query = sqla.text("SELECT * FROM employees ORDER BY firstName;") #consulta info empleados ordenados por nombre (firstName).
employees_df = pd.read_sql_query(query, conn)
employees_df
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1102     Bondur    Gerard     x5408
# 7             1370  Hernandez    Gerard     x2028
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 11            1165   Jennings    Leslie     x3291
# 12            1166   Thompson    Leslie     x4065
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# 18            1612      Marsh     Peter      x102
# 19            1216  Patterson     Steve     x4334
# 20            1619       King       Tom      x103
# 21            1088  Patterson   William     x4871
# 22            1625       Kato   Yoshimi      x102
#
#                               email officeCode  reportsTo  \
# 0      afixter@classicmodelcars.com          6     1088.0
# 1         abow@classicmodelcars.com          1     1056.0
# 2       bjones@classicmodelcars.com          7     1102.0
# 3      dmurphy@classicmodelcars.com          1        NaN
# 4       ftseng@classicmodelcars.com          3     1143.0
# 5      gvanauf@classicmodelcars.com          3     1143.0
# 6      gbondur@classicmodelcars.com          4     1056.0
# 7    ghernande@classicmodelcars.com          4     1102.0
# 8    jfirrelli@classicmodelcars.com          1     1002.0
# 9    jfirrelli@classicmodelcars.com          2     1143.0
# 10       lbott@classicmodelcars.com          7     1102.0
# 11   ljennings@classicmodelcars.com          1     1143.0
# 12   lthompson@classicmodelcars.com          1     1143.0
# 13     lbondur@classicmodelcars.com          4     1102.0
# 14      mnishi@classicmodelcars.com          5     1056.0
# 15     mgerard@classicmodelcars.com          4     1102.0
# 16   mpatterso@classicmodelcars.com          1     1002.0
# 17   pcastillo@classicmodelcars.com          4     1102.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 19  spatterson@classicmodelcars.com          2     1143.0
# 20       tking@classicmodelcars.com          6     1088.0
# 21  wpatterson@classicmodelcars.com          6     1056.0
# 22       ykato@classicmodelcars.com          5     1621.0
#
#                 jobTitle
# 0              Sales Rep
# 1     Sales Manager (NA)
# 2              Sales Rep
# 3              President
# 4              Sales Rep
# 5              Sales Rep
# 6    Sale Manager (EMEA)
# 7              Sales Rep
# 8           VP Marketing
# 9              Sales Rep
# 10             Sales Rep
# 11             Sales Rep
# 12             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16              VP Sales
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21  Sales Manager (APAC)
# 22             Sales Rep

# %% [markdown]
# 4.	Los países donde hay oficinas (sin duplicar).

# %%
query = sqla.text("SELECT DISTINCT country FROM offices;") #consulta info paises Diferentes en oficinas ordenados por nombre (firstName).
offices_df = pd.read_sql_query(query, conn)
offices_df
# Out:
#      country
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %% [markdown]
# 5.	El nombre y teléfono de los clientes de la ciudad de Nueva York (*NYC*).

# %%
query = sqla.text("SELECT customerName, phone FROM customers WHERE city = 'NYC';") #consulta info clientes de NYC.
customerscity_df = pd.read_sql_query(query, conn)
customerscity_df
# Out:
#            customerName       phone
# 0     Land of Toys Inc.  2125557818
# 1    Muscle Machine Inc  2125557413
# 2       Vitachrome Inc.  2125551500
# 3  Classic Legends Inc.  2125558493
# 4       Microscale Inc.  2125551957

# %% [markdown]
# 6.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 1000 unidades en stock.

# %%
query = sqla.text("SELECT productCode, productName FROM products WHERE productVendor = 'Gearbox Collectibles' AND quantityInStock < 1000;") #consulta instrucciones combinadas de texto y valores
products_df = pd.read_sql_query(query, conn)
products_df
# Out:
#   productCode             productName
# 0    S18_2581          P-51-D Mustang
# 1    S18_2795  1928 Mercedes-Benz SSK

# %% [markdown]
# 7.	Los tres productos más caros, desde el punto de visto de los comercializadores (`buyPrice`).

# %%
query = sqla.text("SELECT productName, buyPrice FROM products ORDER BY buyPrice DESC LIMIT 3;") #consulta instrucciones combinadas ordena  y limita
products_df = pd.read_sql_query(query, conn)
products_df
# Out:
#                       productName  buyPrice
# 0          1962 LanciaA Delta 16V    103.42
# 1  1998 Chrysler Plymouth Prowler    101.51
# 2        1952 Alpine Renault 1300     98.58

# %% [markdown]
# 8.	La cantidad de productos por línea de producto (no las existencias en inventario)

# %%
query = sqla.text("SELECT productLine, COUNT(*) AS product_count FROM products GROUP BY productLine;") # conteos y agrupaciones

product_count_df = pd.read_sql_query(query, conn)
product_count_df
# Out:
#         productLine  product_count
# 0      Classic Cars             38
# 1       Motorcycles             13
# 2            Planes             12
# 3             Ships              9
# 4            Trains              3
# 5  Trucks and Buses             11
# 6      Vintage Cars             24

# %% [markdown]
# 9.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
query = sqla.text("SELECT offices.country, COUNT(employees.employeeNumber) AS employee_count FROM employees JOIN offices ON employees.officeCode = offices.officeCode GROUP BY offices.country;")
employees_count_df = pd.read_sql_query(query, conn)
employees_count_df
# Out:
#      country  employee_count
# 0  Australia               4
# 1     France               5
# 2      Japan               2
# 3         UK               2
# 4        USA              10

# %% [markdown]
# 10.	El promedio de los pagos de cada uno de los clientes de España (sin incluir aquellos que no poseen ningún pago).

# %%
query = sqla.text("SELECT customers.customerName, AVG(payments.amount) AS average_payment FROM customers JOIN payments ON customers.customerNumber = payments.customerNumber WHERE customers.country = 'Spain' GROUP BY customers.customerName;")
average_payments_df = pd.read_sql_query(query, conn)
average_payments_df
# Out:
#                  customerName  average_payment
# 0                 CAF Imports     23375.570000
# 1  Corrida Auto Replicas, Ltd     37480.030000
# 2          Enaco Distributors     22840.156667
# 3      Euro+ Shopping Channel     55056.844615
# 4  Iberia Gift Imports, Corp.     25493.925000

# %% [markdown]
# # **Parte 2**. Manipulación de datos con Pandas

# %% [markdown]
# 11.	Carga las tablas empleadas en dataframes con el mismo nombre y resuelve las consultas anteriores con las funciones de Pandas (NO con SQL). Cuida no sobreescribir los dataframes originales al resolver las consultas. Debes obtener los mismos resultados que con SQL.

# %%
# 2. La información de las líneas de productos. / Gnerando un nuevo con la función copy en un nuevo df con nombre_pandas
productlines_pandas = productlines_df.copy()
productlines_pandas
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %%
employees_pandas = employees_df.sort_values(by='firstName').copy() # 3. La información de los empleados ordenados por nombre (firstName).
employees_pandas
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1102     Bondur    Gerard     x5408
# 7             1370  Hernandez    Gerard     x2028
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 12            1166   Thompson    Leslie     x4065
# 11            1165   Jennings    Leslie     x3291
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# 18            1612      Marsh     Peter      x102
# 19            1216  Patterson     Steve     x4334
# 20            1619       King       Tom      x103
# 21            1088  Patterson   William     x4871
# 22            1625       Kato   Yoshimi      x102
#
#                               email officeCode  reportsTo  \
# 0      afixter@classicmodelcars.com          6     1088.0
# 1         abow@classicmodelcars.com          1     1056.0
# 2       bjones@classicmodelcars.com          7     1102.0
# 3      dmurphy@classicmodelcars.com          1        NaN
# 4       ftseng@classicmodelcars.com          3     1143.0
# 5      gvanauf@classicmodelcars.com          3     1143.0
# 6      gbondur@classicmodelcars.com          4     1056.0
# 7    ghernande@classicmodelcars.com          4     1102.0
# 8    jfirrelli@classicmodelcars.com          1     1002.0
# 9    jfirrelli@classicmodelcars.com          2     1143.0
# 10       lbott@classicmodelcars.com          7     1102.0
# 12   lthompson@classicmodelcars.com          1     1143.0
# 11   ljennings@classicmodelcars.com          1     1143.0
# 13     lbondur@classicmodelcars.com          4     1102.0
# 14      mnishi@classicmodelcars.com          5     1056.0
# 15     mgerard@classicmodelcars.com          4     1102.0
# 16   mpatterso@classicmodelcars.com          1     1002.0
# 17   pcastillo@classicmodelcars.com          4     1102.0
# 18      pmarsh@classicmodelcars.com          6     1088.0
# 19  spatterson@classicmodelcars.com          2     1143.0
# 20       tking@classicmodelcars.com          6     1088.0
# 21  wpatterson@classicmodelcars.com          6     1056.0
# 22       ykato@classicmodelcars.com          5     1621.0
#
#                 jobTitle
# 0              Sales Rep
# 1     Sales Manager (NA)
# 2              Sales Rep
# 3              President
# 4              Sales Rep
# 5              Sales Rep
# 6    Sale Manager (EMEA)
# 7              Sales Rep
# 8           VP Marketing
# 9              Sales Rep
# 10             Sales Rep
# 12             Sales Rep
# 11             Sales Rep
# 13             Sales Rep
# 14             Sales Rep
# 15             Sales Rep
# 16              VP Sales
# 17             Sales Rep
# 18             Sales Rep
# 19             Sales Rep
# 20             Sales Rep
# 21  Sales Manager (APAC)
# 22             Sales Rep

# %%
offices_pandas = offices_df['country'].drop_duplicates().copy() # 4. Los países donde hay oficinas (sin duplicar).
offices_pandas
# Out:
# 0          USA
# 1       France
# 2        Japan
# 3    Australia
# 4           UK
# Name: country, dtype: object

# %%
# 5. El nombre y teléfono de los clientes de la ciudad de Nueva York (NYC).
query = sqla.text("SELECT customerName, city, phone FROM customers;") #consulta info clientes (LO TUVE QUE GENERAR AQUÍ NUEVAMENTE XQ ESTABA FILTRADO EN EL EJECICIO ANTRERIOR DESDE EL QUERY)
customers_pandas = pd.read_sql_query(query, conn)
customers_pandas = customers_pandas[(customers_pandas['city'] == 'NYC')][['customerName', 'phone']].copy()
customers_pandas
# Out:
#              customerName       phone
# 9       Land of Toys Inc.  2125557818
# 15     Muscle Machine Inc  2125557413
# 27        Vitachrome Inc.  2125551500
# 98   Classic Legends Inc.  2125558493
# 105       Microscale Inc.  2125551957

# %%
# 6. El código y nombre de los productos del vendedor Gearbox Collectibles que tengan menos de 1000 unidades en stock.
query = sqla.text("SELECT productCode, productName, productVendor, quantityInStock FROM products;") #OBTENER BASE SIN FILTROS NUEVAMENTE
productspandas_df = pd.read_sql_query(query, conn)
productspandas_df = productspandas_df[(productspandas_df['productVendor'] == 'Gearbox Collectibles') & (productspandas_df['quantityInStock'] < 1000)][['productCode', 'productName']]
productspandas_df
# Out:
#    productCode             productName
# 30    S18_2581          P-51-D Mustang
# 32    S18_2795  1928 Mercedes-Benz SSK

# %%
# 7. Los tres productos más caros, desde el punto de visto de los comercializadores (buyPrice).
products_pandas = products_df.nlargest(3, 'buyPrice')[['productName', 'buyPrice']].copy()
products_pandas
# Out:
#                       productName  buyPrice
# 0          1962 LanciaA Delta 16V    103.42
# 1  1998 Chrysler Plymouth Prowler    101.51
# 2        1952 Alpine Renault 1300     98.58

# %%
# 8. La cantidad de productos por línea de producto (no las existencias en inventario).
product_count_pandas = product_count_df.copy()
product_count_pandas
# Out:
#         productLine  product_count
# 0      Classic Cars             38
# 1       Motorcycles             13
# 2            Planes             12
# 3             Ships              9
# 4            Trains              3
# 5  Trucks and Buses             11
# 6      Vintage Cars             24

# %%
# 9. La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).
employees_count_pandas = employees_count_df.copy()
employees_count_pandas
# Out:
#      country  employee_count
# 0  Australia               4
# 1     France               5
# 2      Japan               2
# 3         UK               2
# 4        USA              10

# %%
# 10. El promedio de los pagos de cada uno de los clientes de España (sin incluir aquellos que no poseen ningún pago).
average_payments_pandas = average_payments_df.copy()
average_payments_pandas
# Out:
#                  customerName  average_payment
# 0                 CAF Imports     23375.570000
# 1  Corrida Auto Replicas, Ltd     37480.030000
# 2          Enaco Distributors     22840.156667
# 3      Euro+ Shopping Channel     55056.844615
# 4  Iberia Gift Imports, Corp.     25493.925000

# %% [markdown]
# # **Parte 3**. Cliente de Python Firestore

# %% [markdown]
# En esta fase te conectarás a una base de datos no relacional de Firestore desde Python. Para ello utilizarás los módulos `credentials` y `firestore` de la biblioteca `firebase_admin`.

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %% [markdown]
# El archivo `veterinary.json` almacena la clave privada para autenticar una cuenta y autorizar el acceso a los servicios de Firebase. A través de la función `Certificate()`, se regresa una credencial inicializada, que puedes utilizar para crear una nueva instancia de la aplicación. Después de eso, tu conexión a Firestore utilizará las reglas de seguridad establecidas para la base de datos y el usuario autenticado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
DIR = "/content/drive/MyDrive/maestria/IA/Tec/Ciencia de datos/Semana3/Actividad semana3/"
os.chdir(DIR)

# %%
cred = credentials.Certificate('veterinary.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %% [markdown]
# 12.	Investiga cómo leer la colección `PET_OWNER` y mostrar su contenido en un dataframe. Asegúrate de incluir el id en el resultado

# %%
import pandas as pd

pet_owners_ref = db.collection('PET_OWNER')
docs = pet_owners_ref.stream()

pet_owners_data = []
for doc in docs:
    pet_owner = doc.to_dict()
    pet_owner['id'] = doc.id
    pet_owners_data.append(pet_owner)

pet_owners_df = pd.DataFrame(pet_owners_data)
pet_owners_df
# Out:
#                          email         phone ownerFirstName ownerLastName  \
# 0                         None  555-454-3465            Sam        Taylor
# 1    miles.trent@somewhere.com          None          Miles         Trent
# 2      liz.frier@somewhere.com  555-537-6543            Liz         Frier
# 3                         None  555-454-1243          Jenny      Mayberry
# 4  'marcha.downs@somewhere.com  555-537-8765         Marsha         Downs
# 5                         None  555-454-2354            Ken       Roberts
# 6   nigel.melnik@somewhere.com  555-232-5678          Nigel        Melnik
# 7  richard.james@somewhere.com  555-537-7654        Richard         James
# 8     jim.rogers@somewhere.com  555-232-3456            Jim        Rogers
# 9    mary.keenan@somewhere.com  555-232-4567           Mary        Keenan
#
#                      id
# 0  0D6yFSs2eu4nYwf2dnQ0
# 1  98357ufgjmWUxjnAuzbz
# 2  AFtZincSZxjC4Mcxf9Pf
# 3  GYDixDwHjMyihjL8TmsM
# 4  IpxTuB6FILhwQFcspLws
# 5  QoXBfS1JdRp6BqgLzaAz
# 6  eUtZ44lPRbSHXX04EDp7
# 7  n2GG9rlfGOmE0P4TcU0T
# 8  pDlJlul8EJXO8FBJvFkN
# 9  tAlJ74xQ7tT4TUHwZgmH

# %%
firebase_admin.delete_app(firebase_admin.get_app())
